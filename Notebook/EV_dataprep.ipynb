# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
test_df = pd.read_csv('/content/drive/My Drive/Data/Capstone/test.csv')
train_df = pd.read_csv('/content/drive/My Drive/Data/Capstone/train.csv')
BTS_df = pd.read_csv('/content/drive/My Drive/Data/Capstone/BTS_Data.csv')

# %%
test_df.describe()
# Out:
#        Battery_Capacity_kWh  Discount_Percentage
# count            275.000000           275.000000
# mean              69.440000             8.541818
# std               17.122334             5.717903
# min               40.000000             0.000000
# 25%               56.000000             4.000000
# 50%               69.000000             8.000000
# 75%               83.500000            14.000000
# max              100.000000            20.000000

# %%
train_df.describe()
# Out:
#        Battery_Capacity_kWh  Discount_Percentage  Units_Sold       Revenue
# count            531.000000           531.000000  531.000000  5.310000e+02
# mean              69.408663             9.013183  227.881356  4.918762e+06
# std               17.627504             5.966085   97.905957  2.661565e+06
# min               40.000000             0.000000   50.000000  8.170320e+05
# 25%               53.000000             3.000000  147.000000  2.944326e+06
# 50%               70.000000             8.000000  234.000000  4.575344e+06
# 75%               84.000000            14.000000  313.500000  6.469173e+06
# max              100.000000            20.000000  398.000000  3.016229e+07

# %%
BTS_df.describe()
# Out:
#        Table 1-19:  Hybrid-Electric, Plug-in Hybrid-Electric, and Electric Vehicle Sales  \
# count                                                  10
# unique                                                 10
# top                                       Hybrid electric
# freq                                                    1
#
#        Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# count           4          4          4          4          4          4
# unique          3          3          3          3          3          3
# top             Z          Z          Z          Z          Z          Z
# freq            2          2          2          2          2          2
#
#        Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 16 Unnamed: 17  \
# count           4          4          4  ...           4           4
# unique          3          3          3  ...           4           4
# ...

# %%
test_df.info()
train_df.info()
BTS_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  275 non-null    object
#  1   Region                275 non-null    object
#  2   Brand                 275 non-null    object
#  3   Model                 275 non-null    object
#  4   Vehicle_Type          275 non-null    object
#  5   Battery_Capacity_kWh  275 non-null    int64
#  6   Discount_Percentage   275 non-null    int64
#  7   Customer_Segment      275 non-null    object
#  8   Fast_Charging_Option  275 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 19.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  531 non-null    object
# ...

# %%
print(test_df.dtypes)
# Out:
# Date                    object
# Region                  object
# Brand                   object
# Model                   object
# Vehicle_Type            object
# Battery_Capacity_kWh     int64
# Discount_Percentage      int64
# Customer_Segment        object
# Fast_Charging_Option    object
# dtype: object

# %%
print(train_df.dtypes)
# Out:
# Date                    object
# Region                  object
# Brand                   object
# Model                   object
# Vehicle_Type            object
# Battery_Capacity_kWh     int64
# Discount_Percentage      int64
# Customer_Segment        object
# Fast_Charging_Option    object
# Units_Sold               int64
# Revenue                  int64
# dtype: object

# %%
print(BTS_df.dtypes)
# Out:
# Table 1-19:  Hybrid-Electric, Plug-in Hybrid-Electric, and Electric Vehicle Sales    object
# Unnamed: 1                                                                           object
# Unnamed: 2                                                                           object
# Unnamed: 3                                                                           object
# Unnamed: 4                                                                           object
# Unnamed: 5                                                                           object
# Unnamed: 6                                                                           object
# Unnamed: 7                                                                           object
# Unnamed: 8                                                                           object
# Unnamed: 9                                                                           object
# ...

# %%
test_df.head()
# Out:
#       Date         Region       Brand       Model Vehicle_Type  \
# 0  2023-04        Oceania  Volkswagen     Model 3          SUV
# 1  2023-10        Oceania        Ford     Model 3        Sedan
# 2  2023-10  South America  Volkswagen      Atto 3        Sedan
# 3  2023-02         Africa  Volkswagen  Corolla EV    Crossover
# 4  2023-10  North America       Tesla      Rio EV        Sedan
#
#    Battery_Capacity_kWh  Discount_Percentage  Customer_Segment  \
# 0                    45                   16  Budget Conscious
# 1                    89                    5   Tech Enthusiast
# 2                    61                    4  Budget Conscious
# 3                   100                   16     Eco-Conscious
# 4                    70                    8     Eco-Conscious
#
#   Fast_Charging_Option
# 0                   No
# 1                  Yes
# 2                  Yes
# 3                   No
# 4                  Yes

# %%
test_df['Date'] = pd.to_datetime(test_df['Date'], format = "%Y-%m")
print(test_df.dtypes)
# Out:
# Date                    datetime64[ns]
# Region                          object
# Brand                           object
# Model                           object
# Vehicle_Type                    object
# Battery_Capacity_kWh             int64
# Discount_Percentage              int64
# Customer_Segment                object
# Fast_Charging_Option            object
# dtype: object

# %%
train_df['Date'] = pd.to_datetime(train_df['Date'], format = "%Y-%m")
print(train_df.dtypes)
# Out:
# Date                    datetime64[ns]
# Region                          object
# Brand                           object
# Model                           object
# Vehicle_Type                    object
# Battery_Capacity_kWh             int64
# Discount_Percentage              int64
# Customer_Segment                object
# Fast_Charging_Option            object
# Units_Sold                       int64
# Revenue                          int64
# dtype: object

# %%
import pandas as pd

bts_updated = {
    "Year": [2010, 2011, 2012, 2013, 2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],
    "Hybrid Electric": [274684, 268749, 434648, 495535, 452172, 384400, 346949, 370680,338149, 399444, 455067, 799046, 766412, 1175456, 1609035],
    "Plug-in Hybrid Electric": [326, 7671, 38584, 49008, 55357, 43008, 72885, 91188, 123883, 85791, 69049, 176117, 183422, 293578, 321774],
    "Electric": [19, 10092, 14587, 48094, 63525, 71064, 86731, 104487, 207062, 233822, 238540, 459474, 747982, 1164638, 1247656]
}

bts_df = pd.DataFrame(bts_updated)

print(bts_df)
# Out:
#     Year  Hybrid Electric  Plug-in Hybrid Electric  Electric
# 0   2010           274684                      326        19
# 1   2011           268749                     7671     10092
# 2   2012           434648                    38584     14587
# 3   2013           495535                    49008     48094
# 4   2014           452172                    55357     63525
# 5   2015           384400                    43008     71064
# 6   2016           346949                    72885     86731
# 7   2017           370680                    91188    104487
# 8   2018           338149                   123883    207062
# 9   2019           399444                    85791    233822
# 10  2020           455067                    69049    238540
# 11  2021           799046                   176117    459474
# 12  2022           766412                   183422    747982
# 13  2023          1175456                   293578   1164638
# ...

# %%
display(test_df.isnull().sum())
# Out:
# Date                    0
# Region                  0
# Brand                   0
# Model                   0
# Vehicle_Type            0
# Battery_Capacity_kWh    0
# Discount_Percentage     0
# Customer_Segment        0
# Fast_Charging_Option    0
# dtype: int64

# %%
display(train_df.isnull().sum())
# Out:
# Date                    0
# Region                  0
# Brand                   0
# Model                   0
# Vehicle_Type            0
# Battery_Capacity_kWh    0
# Discount_Percentage     0
# Customer_Segment        0
# Fast_Charging_Option    0
# Units_Sold              0
# Revenue                 0
# dtype: int64

# %%
display(bts_df.isnull().sum())
# Out:
# Year                       0
# Hybrid Electric            0
# Plug-in Hybrid Electric    0
# Electric                   0
# dtype: int64

# %%
bts_df.to_csv('/content/drive/My Drive/Data/Capstone/bts_data.csv', index=False)
